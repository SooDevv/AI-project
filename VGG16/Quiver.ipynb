# %% [markdown]
# # Quiver
# - model : VGG16
# - reference
#     * https://github.com/keplr-io/quiver
#     * https://www.youtube.com/watch?edit=vd&v=tgRW3BRi_FA

# %% [markdown]
# ### Input
# ![image](https://user-images.githubusercontent.com/33097467/45812663-5e594a00-bd0b-11e8-90ac-efce763d78ea.png)

# %% [markdown]
# ### Block1 - Conv
# ![image](https://user-images.githubusercontent.com/33097467/45812736-9c566e00-bd0b-11e8-9a9a-481fdf2b5e08.png)

# %% [markdown]
# ## Block2 - Conv, Pool
# ![image](https://user-images.githubusercontent.com/33097467/45813127-b9d80780-bd0c-11e8-988f-2e090efa7695.png)
# ![image](https://user-images.githubusercontent.com/33097467/45813237-00c5fd00-bd0d-11e8-9cab-03657e80f0cd.png)

# %% [markdown]
# ## Block3 - Conv
# ![image](https://user-images.githubusercontent.com/33097467/45813324-4c78a680-bd0d-11e8-9d98-bdf8eb43c1b4.png)
# ![image](https://user-images.githubusercontent.com/33097467/45813486-ada07a00-bd0d-11e8-97a9-019cdf1fce34.png)

# %% [markdown]
# ## Block4- Conv1, Conv2, Conv3
# ![image](https://user-images.githubusercontent.com/33097467/45813594-01ab5e80-bd0e-11e8-97f4-c8bdaa5652f0.png)
# ![image](https://user-images.githubusercontent.com/33097467/45813673-30293980-bd0e-11e8-8aef-211eb04a4e94.png)
# ![image](https://user-images.githubusercontent.com/33097467/45813708-50f18f00-bd0e-11e8-9e07-3f6ce3718fef.png)

# %% [markdown]
# ## Block5 - Conv
# ![image](https://user-images.githubusercontent.com/33097467/45813766-7a121f80-bd0e-11e8-9940-ccd345c1e3f7.png)

# %% [markdown]
# ---

# %%
from keras.applications.vgg16 import VGG16

# %%
model = VGG16()

# %%
dir(model)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_inbound_node',
#  '_base_init',
#  '_built',
#  '_check_trainable_weights_consistency',
#  '_compute_previous_mask',
#  '_expects_training_arg',
#  '_feed_input_names',
#  '_feed_input_shapes',
#  '_feed_inputs',
#  '_get_node_attribute_at_index',
#  '_inbound_nodes',
#  '_init_graph_network',
#  '_init_subclassed_network',
#  '_initial_weights',
#  '_input_coordinates',
#  '_input_layers',
#  '_is_compiled',
#  '_is_graph_network',
#  '_layers',
#  '_layers_by_depth',
#  '_losses',
#  '_make_predict_function',
#  '_make_test_function',
# ...

# %%
model.__str__()
# Out:
# '<keras.engine.training.Model object at 0x0000021342ACE0B8>'

# %%
# !pip install git+git://github.com/keplr-io/quiver.git
# Out:
# ...
#   Cloning git://github.com/keplr-io/quiver.git to c:\users\sj\appdata\local\temp\pip-req-build-sbw36b9d
# ...
#   Running setup.py bdist_wheel for quiver-engine: started
#   Running setup.py bdist_wheel for quiver-engine: finished with status 'done'
#   Stored in directory: C:\Users\sj\AppData\Local\Temp\pip-ephem-wheel-cache-fca9lre3\wheels\f8\3d\8c\01767f90bbdb04d278ca603ff5411b06a8778421a7bd01c720
# Successfully built quiver-engine
# ...

# %%
from quiver_engine.server import launch
# Out:
# Using TensorFlow backend.

# %%
launch(model, input_folder='./img', port=7000)
# Out:
# Starting webserver from: C:\Program Files\Anaconda3\lib\site-packages\quiver_engine
# ::1 - - [2018-09-20 19:15:39] "GET /model HTTP/1.1" 200 11079 0.005037
# ::1 - - [2018-09-20 19:15:39] "GET /inputs HTTP/1.1" 200 192 0.000998
# Warning! you didn't pass your own set of classes for the model therefore imagenet classes are used
# ::1 - - [2018-09-20 19:16:01] "GET /predict/cat.jpg HTTP/1.1" 200 373 0.644190
# C:\Program Files\Anaconda3\lib\site-packages\quiver_engine\layer_result_generators.py:7: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("bl...)`
#   output=model.get_layer(layer_name).output
# ::1 - - [2018-09-20 19:16:04] "GET /layer/block2_conv2/cat.jpg HTTP/1.1" 200 4002 2.458297
# ::1 - - [2018-09-20 19:16:04] "GET /temp-file/block2_conv2_0_cat.jpg.png HTTP/1.1" 200 8180 0.006876
# ::1 - - [2018-09-20 19:16:04] "GET /temp-file/block2_conv2_1_cat.jpg.png HTTP/1.1" 200 6904 0.004430
# ...
